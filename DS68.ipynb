# %% [markdown]
# <a href="https://colab.research.google.com/github/sahil-randhe/Artificial_Intelligence_Lab_SE_B_68/blob/master/DS68.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def factorial(n):
    """Calculates the factorial of a non-negative integer n."""
    if not isinstance(n, int) or n < 0:
        raise ValueError("Input must be a non-negative integer")
    if n == 0:
        return 1
    else:
        result = 1
        for i in range(1, n + 1):
            result *= i
        return result

# Example usage:
num = 5
try:
    print(f"The factorial of {num} is {factorial(num)}")
    print(f"The factorial of 0 is {factorial(0)}")
    # Uncomment the line below to test error handling for negative numbers
    # print(f"The factorial of -3 is {factorial(-3)}")
except ValueError as e:
    print(f"Error: {e}")
# Out:
# The factorial of 5 is 120
# The factorial of 0 is 1
